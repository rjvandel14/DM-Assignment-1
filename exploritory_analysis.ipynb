# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_mood_smartphone.csv', index_col = 0)
df.head()
# Out:
#         id                     time variable  value
# 1  AS14.01  2014-02-26 13:00:00.000     mood    6.0
# 2  AS14.01  2014-02-26 15:00:00.000     mood    6.0
# 3  AS14.01  2014-02-26 18:00:00.000     mood    6.0
# 4  AS14.01  2014-02-26 21:00:00.000     mood    7.0
# 5  AS14.01  2014-02-27 09:00:00.000     mood    6.0

# %%
variables = df["variable"].unique()
len(variables)
# Out:
# 19

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
print(df['time'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ### Exploratory analysis

# %%
n = len(df)
n
# Out:
# 376912

# %%
missing = df.isnull().sum()
missing
# Out:
# id            0
# time          0
# variable      0
# value       202
# dtype: int64

# %%
descriptive_stats_list = []

for i in variables:
    temp_df = df.loc[df['variable'] == i].copy()
    temp_df = temp_df.drop(['time'], axis=1)

    stats = temp_df.describe()
    median = temp_df['value'].median()
    skewness = temp_df['value'].skew()
    kurtosis = temp_df['value'].kurt()

    missing_values = temp_df.isnull().sum()
    variable_stats = {
        'Stats': stats,
        "Median": median,
        'Missing_values': missing_values,
        'Skewness': skewness,
        "Kurtosis": kurtosis

    }
    descriptive_stats_list.append((i, variable_stats))

for i, stats_data in descriptive_stats_list:
    print(f"Descriptive stats for variable {i}:")
    print(stats_data['Stats'])
    print(f"Missing values for variable {i}:")
    print(stats_data['Missing_values'])
    print(f"Skewness of  {i}:", stats_data['Skewness'])
    print(f"median of  {i}:",  stats_data['Median'])
    print("\n")
# Out:
# Descriptive stats for variable mood:
#              value
# count  5641.000000
# mean      6.992555
# std       1.032769
# min       1.000000
# 25%       7.000000
# 50%       7.000000
# 75%       8.000000
# max      10.000000
# Missing values for variable mood:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  mood: -0.8333525575926262
# median of  mood: 7.0
#
#
# Descriptive stats for variable circumplex.arousal:
#              value
# count  5597.000000
# mean     -0.098624
# std       1.051868
# min      -2.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000
# Missing values for variable circumplex.arousal:
# id           0
# variable     0
# value       46
# dtype: int64
# Skewness of  circumplex.arousal: -0.07629620339030749
# median of  circumplex.arousal: 0.0
#
#
# Descriptive stats for variable circumplex.valence:
#              value
# count  5487.000000
# mean      0.687808
# std       0.671298
# min      -2.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Missing values for variable circumplex.valence:
# id            0
# variable      0
# value       156
# dtype: int64
# Skewness of  circumplex.valence: -1.0299201305472279
# median of  circumplex.valence: 1.0
#
#
# Descriptive stats for variable activity:
#               value
# count  22965.000000
# mean       0.115958
# std        0.186946
# min        0.000000
# 25%        0.000000
# 50%        0.021739
# 75%        0.158333
# max        1.000000
# Missing values for variable activity:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  activity: 2.0904762592906705
# median of  activity: 0.0217391304347826
#
#
# Descriptive stats for variable screen:
#               value
# count  96578.000000
# mean      75.335206
# std      253.822497
# min        0.035000
# 25%        5.322250
# 50%       20.044500
# 75%       62.540250
# max     9867.007000
# Missing values for variable screen:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  screen: 15.672235330438227
# median of  screen: 20.04449999332425
#
#
# Descriptive stats for variable call:
#         value
# count  5239.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Missing values for variable call:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  call: 0.0
# median of  call: 1.0
#
#
# Descriptive stats for variable sms:
#         value
# count  1798.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Missing values for variable sms:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  sms: 0.0
# median of  sms: 1.0
#
#
# Descriptive stats for variable appCat.builtin:
#               value
# count  91288.000000
# mean      18.538262
# std      415.989243
# min   -82798.871000
# 25%        2.020000
# 50%        4.038000
# 75%        9.922000
# max    33960.246000
# Missing values for variable appCat.builtin:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.builtin: -57.82341403717343
# median of  appCat.builtin: 4.038
#
#
# Descriptive stats for variable appCat.communication:
#               value
# count  74276.000000
# mean      43.343792
# std      128.912750
# min        0.006000
# 25%        5.218000
# 50%       16.225500
# 75%       45.475750
# max     9830.777000
# Missing values for variable appCat.communication:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.communication: 29.352377881029994
# median of  appCat.communication: 16.2255
#
#
# Descriptive stats for variable appCat.entertainment:
#               value
# count  27125.000000
# mean      37.576480
# std      262.960476
# min       -0.011000
# 25%        1.334000
# 50%        3.391000
# 75%       14.922000
# max    32148.677000
# Missing values for variable appCat.entertainment:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.entertainment: 78.06709002951024
# median of  appCat.entertainment: 3.391
#
#
# Descriptive stats for variable appCat.finance:
#             value
# count  939.000000
# mean    21.755251
# std     39.218361
# min      0.131000
# 25%      4.072000
# 50%      8.026000
# 75%     20.155000
# max    355.513000
# Missing values for variable appCat.finance:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.finance: 4.236486405721144
# median of  appCat.finance: 8.026
#
#
# Descriptive stats for variable appCat.game:
#              value
# count   813.000000
# mean    128.391615
# std     327.145246
# min       1.003000
# 25%      14.148000
# 50%      43.168000
# 75%     123.625000
# max    5491.793000
# Missing values for variable appCat.game:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.game: 9.690749665088353
# median of  appCat.game: 43.168
#
#
# Descriptive stats for variable appCat.office:
#               value
# count   5642.000000
# mean      22.578892
# std      449.601382
# min        0.003000
# 25%        2.004000
# 50%        3.106000
# 75%        8.043750
# max    32708.818000
# Missing values for variable appCat.office:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.office: 68.67616896857685
# median of  appCat.office: 3.106
#
#
# Descriptive stats for variable appCat.other:
#              value
# count  7650.000000
# mean     25.810839
# std     112.781355
# min       0.014000
# 25%       7.019000
# 50%      10.028000
# 75%      16.829250
# max    3892.038000
# Missing values for variable appCat.other:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.other: 21.324189006502312
# median of  appCat.other: 10.028
#
#
# Descriptive stats for variable appCat.social:
#               value
# count  19145.000000
# mean      72.401906
# std      261.551846
# min        0.094000
# 25%        9.030000
# 50%       28.466000
# 75%       75.372000
# max    30000.906000
# Missing values for variable appCat.social:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.social: 80.21723554055497
# median of  appCat.social: 28.466
#
#
# Descriptive stats for variable appCat.travel:
#               value
# count   2846.000000
# mean      45.730850
# std      246.109307
# min        0.080000
# 25%        5.086500
# 50%       18.144000
# 75%       47.227250
# max    10452.615000
# Missing values for variable appCat.travel:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.travel: 34.01350737930217
# median of  appCat.travel: 18.144
#
#
# Descriptive stats for variable appCat.unknown:
#              value
# count   939.000000
# mean     45.553006
# std     119.400405
# min       0.111000
# 25%       5.018000
# 50%      17.190000
# 75%      44.430500
# max    2239.937000
# Missing values for variable appCat.unknown:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.unknown: 9.93062521020431
# median of  appCat.unknown: 17.19
#
#
# Descriptive stats for variable appCat.utilities:
#              value
# count  2487.000000
# mean     18.537552
# std      60.959134
# min       0.246000
# 25%       3.158500
# 50%       8.030000
# 75%      19.331000
# max    1802.649000
# Missing values for variable appCat.utilities:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.utilities: 18.114170013998574
# median of  appCat.utilities: 8.03
#
#
# Descriptive stats for variable appCat.weather:
#             value
# count  255.000000
# mean    20.148714
# std     24.943431
# min      1.003000
# 25%      8.684000
# 50%     15.117000
# 75%     25.349000
# max    344.863000
# Missing values for variable appCat.weather:
# id          0
# variable    0
# value       0
# dtype: int64
# Skewness of  appCat.weather: 8.947835070185649
# median of  appCat.weather: 15.117

# %%
for i in variables:
    subset = df[df['variable'] == i]
    
    plt.figure(figsize=(10, 6))
    plt.hist(subset['value'], bins=50, edgecolor='black', alpha=0.7)
    plt.title(f"Histogram for {i}")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# %%
for i in variables:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='value', data=df[df['variable'] == i])

    plt.title(f"Boxplot for {i}")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()
